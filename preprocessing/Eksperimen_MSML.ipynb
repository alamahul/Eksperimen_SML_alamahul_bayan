# %% [markdown]
# # **1. Perkenalan Dataset**

# %% [markdown]
# Tahap pertama, Anda harus mencari dan menggunakan dataset dengan ketentuan sebagai berikut:
#
# 1. **Sumber Dataset**:
#    Dataset dapat diperoleh dari berbagai sumber, seperti public repositories (*Kaggle*, *UCI ML Repository*, *Open Data*) atau data primer yang Anda kumpulkan sendiri.

# %% [markdown]
# # **2. Import Library**

# %% [markdown]
# Pada tahap ini, Anda perlu mengimpor beberapa pustaka (library) Python yang dibutuhkan untuk analisis data dan pembangunan model machine learning atau deep learning.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Memastikan visualisasi muncul di dalam notebook
# %matplotlib inline

# %% [markdown]
# # **3. Memuat Dataset**

# %% [markdown]
# Pada tahap ini, Anda perlu memuat dataset ke dalam notebook. Jika dataset dalam format CSV, Anda bisa menggunakan pustaka pandas untuk membacanya. Pastikan untuk mengecek beberapa baris awal dataset untuk memahami strukturnya dan memastikan data telah dimuat dengan benar.
#
# Jika dataset berada di Google Drive, pastikan Anda menghubungkan Google Drive ke Colab terlebih dahulu. Setelah dataset berhasil dimuat, langkah berikutnya adalah memeriksa kesesuaian data dan siap untuk dianalisis lebih lanjut.
#
# Jika dataset berupa unstructured data, silakan sesuaikan dengan format seperti kelas Machine Learning Pengembangan atau Machine Learning Terapan

# %%
# Memuat dataset ke dalam DataFrame
df = pd.read_csv('/content/movie_genre_classification_final.csv')

# Menampilkan 5 baris pertama untuk memastikan data termuat dengan benar
display(df.head())
# Out:
#              Title  Year  Director  Duration  Rating     Votes  \
# 0  Winds of Fate 4  1980    R. Lee       167     4.1  182425.0
# 1     Firestorm 11  2014   S. Chen       166     4.1  449351.0
# 2    Silent Echo 2  2016   A. Khan       170     4.1  363328.0
# 3    City Lights 4  1982  L. Zhang       170     9.9   62371.0
# 4   Broken Truth 1  1990  L. Zhang        91     5.3    4600.0
#
#                                          Description  Language Country  \
# 0   A touching love story with heartwarming moments.   Spanish   China
# 1  A fast-paced thriller with intense action scenes.    Korean   China
# 2  A fast-paced thriller with intense action scenes.    Korean   Japan
# 3  An emotional journey exploring complex charact...  Japanese   Japan
# 4  An imaginative world filled with magic and won...    Korean     USA
#
#     Budget_USD  BoxOffice_USD    Genre Production_Company Content_Rating  \
# 0   39979615.0    179936008.0  Romance         DreamWorks              R
# 1  116404774.0    802121619.0   Action            Netflix              R
# 2  166261330.0    225526871.0   Action              Pixar             PG
# 3   28861315.0     69813738.0    Drama            Netflix          NC-17
# 4   43890403.0    375136716.0  Fantasy      Studio Ghibli             PG
#
#          Lead_Actor  Num_Awards  Critic_Reviews
# 0    Kangana Ranaut         8.0           229.0
# 1    Kangana Ranaut        20.0           466.0
# 2  Amitabh Bachchan        16.0           539.0
# 3   Natalie Portman        15.0           606.0
# 4       Chris Evans         6.0           330.0

# %% [markdown]
# # **4. Exploratory Data Analysis (EDA)**
#
# Pada tahap ini, Anda akan melakukan **Exploratory Data Analysis (EDA)** untuk memahami karakteristik dataset.
#
# Tujuan dari EDA adalah untuk memperoleh wawasan awal yang mendalam mengenai data dan menentukan langkah selanjutnya dalam analisis atau pemodelan.

# %%
# Melihat informasi umum (jumlah baris, kolom, dan tipe data)
print("=== Informasi Dataset ===")
df.info()
print("\n")

# Melihat statistik deskriptif untuk kolom numerik
print("=== Statistik Deskriptif ===")
display(df.describe())

# Visualisasi distribusi target (Genre)
plt.figure(figsize=(10, 5))
sns.countplot(data=df, x='Genre', palette='Set2')
plt.title('Distribusi Genre Film')
plt.xlabel('Genre')
plt.ylabel('Jumlah')
plt.show()
# Out:
# === Informasi Dataset ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42865 entries, 0 to 42864
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Title               42865 non-null  object
#  1   Year                42865 non-null  int64
#  2   Director            42865 non-null  object
#  3   Duration            42865 non-null  int64
#  4   Rating              42864 non-null  float64
#  5   Votes               42864 non-null  float64
#  6   Description         42864 non-null  object
#  7   Language            42864 non-null  object
#  8   Country             42864 non-null  object
#  9   Budget_USD          42864 non-null  float64
#  10  BoxOffice_USD       42864 non-null  float64
#  11  Genre               42864 non-null  object
#  12  Production_Company  42864 non-null  object
#  13  Content_Rating      42864 non-null  object
#  14  Lead_Actor          42864 non-null  object
#  15  Num_Awards          42864 non-null  float64
#  16  Critic_Reviews      42864 non-null  float64
# dtypes: float64(6), int64(2), object(9)
# memory usage: 5.6+ MB
#
#
# === Statistik Deskriptif ===
#                Year      Duration        Rating          Votes    Budget_USD  \
# count  42865.000000  42865.000000  42864.000000   42864.000000  4.286400e+04
# mean    2001.544593    130.045795      6.931206  250001.945735  9.185348e+07
# std       12.725008     29.124093      1.698841  144155.169419  5.820033e+07
# min     1980.000000      1.000000      4.000000     544.000000  1.135566e+06
# 25%     1991.000000    105.000000      5.500000  124632.000000  4.389040e+07
# 50%     2002.000000    130.000000      6.900000  249011.500000  8.062480e+07
# 75%     2013.000000    155.000000      8.400000  374960.500000  1.475557e+08
# max     2023.000000    180.000000      9.900000  499984.000000  1.984445e+08
#
#        BoxOffice_USD    Num_Awards  Critic_Reviews
# count   4.286400e+04  42864.000000    42864.000000
# mean    5.183088e+08      9.960363      499.882745
# std     2.879313e+08      6.060870      289.793498
# min     3.291117e+06      0.000000        0.000000
# 25%     2.848425e+08      5.000000      248.000000
# 50%     5.109973e+08     10.000000      500.000000
# 75%     7.704129e+08     15.000000      750.000000
# max     9.925159e+08     20.000000     1000.000000
# /tmp/ipykernel_2239/1063305240.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Genre', palette='Set2')

# %% [markdown]
# # **5. Data Preprocessing**

# %% [markdown]
# Pada tahap ini, data preprocessing adalah langkah penting untuk memastikan kualitas data sebelum digunakan dalam model machine learning.
#
# Jika Anda menggunakan data teks, data mentah sering kali mengandung nilai kosong, duplikasi, atau rentang nilai yang tidak konsisten, yang dapat memengaruhi kinerja model. Oleh karena itu, proses ini bertujuan untuk membersihkan dan mempersiapkan data agar analisis berjalan optimal.
#
# Berikut adalah tahapan-tahapan yang bisa dilakukan, tetapi **tidak terbatas** pada:
# 1. Menghapus atau Menangani Data Kosong (Missing Values)
# 2. Menghapus Data Duplikat
# 3. Normalisasi atau Standarisasi Fitur
# 4. Deteksi dan Penanganan Outlier
# 5. Encoding Data Kategorikal
# 6. Binning (Pengelompokan Data)
#
# Cukup sesuaikan dengan karakteristik data yang kamu gunakan yah. Khususnya ketika kami menggunakan data tidak terstruktur.

# %%
# 1. Mengecek dan menghapus data duplikat
jumlah_duplikat = df.duplicated().sum()
print(f"Jumlah data duplikat: {jumlah_duplikat}")
df = df.drop_duplicates()

# 2. Mengecek data kosong (Missing Values)
print("\nJumlah missing values pada tiap kolom:")
print(df.isnull().sum())

# Jika ada data kosong, kita drop baris tersebut (opsional, tergantung hasil di atas)
df = df.dropna()

# 3. Drop kolom yang tidak relevan untuk model tabular dasar
# Title dan Description adalah teks unik, kita hapus agar tidak membingungkan model
kolom_dihapus = ['Title', 'Description']
df_bersih = df.drop(columns=kolom_dihapus)

# 4. Encoding Data Kategorikal (Mengubah teks menjadi angka)
# Kolom seperti Director, Language, Country, dll perlu diubah ke numerik
# Kita gunakan pd.get_dummies (One-Hot Encoding)
kolom_kategori = ['Director', 'Language', 'Country', 'Production_Company', 'Content_Rating', 'Lead_Actor']
df_bersih = pd.get_dummies(df_bersih, columns=kolom_kategori, drop_first=True)

# Tampilkan data yang sudah bersih
print("\nData setelah preprocessing:")
display(df_bersih.head())
# Out:
# Jumlah data duplikat: 0
#
# Jumlah missing values pada tiap kolom:
# Title                 0
# Year                  0
# Director              0
# Duration              0
# Rating                1
# Votes                 1
# Description           1
# Language              1
# Country               1
# Budget_USD            1
# BoxOffice_USD         1
# Genre                 1
# Production_Company    1
# Content_Rating        1
# Lead_Actor            1
# Num_Awards            1
# Critic_Reviews        1
# dtype: int64
#
# Data setelah preprocessing:
#    Year  Duration  Rating     Votes   Budget_USD  BoxOffice_USD    Genre  \
# 0  1980       167     4.1  182425.0   39979615.0    179936008.0  Romance
# 1  2014       166     4.1  449351.0  116404774.0    802121619.0   Action
# 2  2016       170     4.1  363328.0  166261330.0    225526871.0   Action
# 3  1982       170     9.9   62371.0   28861315.0     69813738.0    Drama
# 4  1990        91     5.3    4600.0   43890403.0    375136716.0  Fantasy
#
#    Num_Awards  Critic_Reviews  Director_D. Patel  ...  Content_Rating_R  \
# 0         8.0           229.0              False  ...              True
# 1        20.0           466.0              False  ...              True
# 2        16.0           539.0              False  ...             False
# 3        15.0           606.0              False  ...             False
# 4         6.0           330.0              False  ...             False
#
#    Lead_Actor_Anne Hathaway  Lead_Actor_Brad Pitt  Lead_Actor_Chris Evans  \
# 0                     False                 False                   False
# 1                     False                 False                   False
# 2                     False                 False                   False
# 3                     False                 False                   False
# 4                     False                 False                    True
#
#    Lead_Actor_Emma Watson  Lead_Actor_Kangana Ranaut  \
# 0                   False                       True
# 1                   False                       True
# 2                   False                      False
# 3                   False                      False
# 4                   False                      False
#
#    Lead_Actor_Leonardo DiCaprio  Lead_Actor_Natalie Portman  \
# 0                         False                       False
# 1                         False                       False
# 2                         False                       False
# 3                         False                        True
# 4                         False                       False
#
#    Lead_Actor_Shah Rukh Khan  Lead_Actor_Tom Hanks
# 0                      False                 False
# 1                      False                 False
# 2                      False                 False
# 3                      False                 False
# 4                      False                 False
#
# [5 rows x 52 columns]
